# %% [markdown]
# # Лабораторная работа 1.2 Нелинейные фильтры

# %% [markdown]
# ### Работу выполнил:<span style="color:blue"> Иззатов Эльшан</span>

# %% [markdown]
# ### Сделанную лабораторную работу отправляйте через [ФОРМУ](https://vyatsu-my.sharepoint.com/:f:/g/personal/usr09019_vyatsu_ru/Ep8q6AurefNIlDOa12RT5YwBtwdfbgDDo0pXpRQjJI3wpQ)

# %% [markdown]
# **Задание 1.1.** Реализуйте медианный фильтр. P.s. здесь берём нелинейный фильтр суть в том что мы берём медианное значение, есть окошко в котором значение интенсивности пикселей 25 130 40 70 15 240 179 10 96. Для каждого положения окна считаем интенсивность пикселей в окне. Медианный фильтр лучше обрабатывает шум, который не является Гауссом. Например, при сканировании могут выделяться другие цвета.

# %%
import cv2
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/Компьютерное зрение/Лекции/Лекция 1/lena.png')

# %%
plt.imshow(img[...,::-1])

# %%
img.shape

# %%
def median_filter(img, ksize):
    result = np.zeros_like(img)
    for channel in range(img.shape[-1]):
        for row in range(img.shape[0]):
            for col in range(img.shape[1]):
                result[row, col, channel] = img[row, col, channel]
                # TODO: определяем текущее положение окна в координатах изображения
                # TODO: вычислить медиану в окрестности х, y для окна размера ksize
    return result

# %% [markdown]
# **Задание 1.2.** Добавьте случайный шум на изображение и протестируйте медианный фильтр на зашумленном изображении (код приведён).

# %%
noisy_img = img.astype(float) + np.random.uniform(img.astype(float))
noisy_img = np.uint8(255. * np.abs(noisy_img) / np.max(np.abs(noisy_img)))
plt.imshow(noisy_img[...,::-1])

# %%
from ipywidgets import interact

def median_filter_show(ksize = 5):
    filtered = median_filter(noisy_img, ksize)
    return plt.imshow(filtered[...,::-1]);

interact(median_filter_show, ksize = (1, 20, 1));

# %% [markdown]
# **Задание 1.3.** Реализуйте билатеральный фильтр (см. лекции и https://users.soe.ucsc.edu/~manduchi/Papers/ICCV98.pdf). Протестируйте данный фильтр при различных значениях $\sigma_d$ и $\sigma_r$. P.s. есть ссылка на статью с примерами внизу статьи, реализовать билатеральный фильтр из лекции с 59 страницы презентация. Можно применить к зашумлённому изображению или оригинальному.
